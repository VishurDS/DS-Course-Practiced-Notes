# %%
a=10

# %%
a
# Out:
# 10

# %% [markdown]
# ## This is intro session
#
# ### Welcome to Data Science Masters batch
#
# This test example for markdown

# %%
print(a)
# Out:
# 10

# %%
1+1
# Out:
# 2

# %%
## This is a single line comment with dobule #
## comments
# Single line comment with single #
a=20
a
# Out:
# 20

# %% [markdown]
# ### For multiline comments we will use triple quotes """ """ or ''' '''

# %%
'''
Hello
this is a example of multiline comments
This will also be ignored by kernal
'''
a= 20
print(a)
# Out:
# 20

# %% [markdown]
# ### Starting Here with Day 1
#
# # Numbers

# %%
1+2
# Out:
# 3

# %%
## what if we do the same thing with print statement
print(1+2)  #This is just a output console
# Out:
# 3

# %%
5
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %% [markdown]
# Print Statement

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
#   Shift + Tab on function will give you function info

# %%
print("Hello my name is Vishal and
      I am Data Science Enthusiast")
# Out:
#   Cell In[3], line 1
#     print("Hello my name is Vishal and
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Hello my name is Vishal and \n I am Data Science Enthusiast")
# Out:
# Hello my name is Vishal and
#  I am Data Science Enthusiast

# %%
print("Hello my name is Vishal and \nI am Data Science Enthusiast")
# Out:
# Hello my name is Vishal and
# I am Data Science Enthusiast

# %% [markdown]
# ## Variable Assignment

# %%
name = "Vishal"
age = 29

# %%
name
# Out:
# 'Vishal'

# %%
age
# Out:
# 29

# %%
number = 10

# %%
number
# Out:
# 10

# %%
print(number)
# Out:
# 10

# %%
name = 'Bala' #now name variable will be updated/replaced by new name

# %%
print(name)
# Out:
# Bala

# %%
#empty string
""
# Out:
# ''

# %% [markdown]
# ### type()
# function to check the datatype

# %%
type(name)
# Out:
# str

# %%
decimal_number = 2.5

# %%
decimal_number
# Out:
# 2.5

# %%
type(decimal_number)
# Out:
# float

# %% [markdown]
# press 'tab' for autocompletion

# %%
#complex number

2+4j
# Out:
# (2+4j)

# %%
type(2+4j)
# Out:
# complex

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %% [markdown]
# 1. Don't write variable name with number
# 2. Variable are case sensitive
# 3. Don't use reserved keyword as variable name
#
# some of the reserved keyword are str, len, bool, complex, return, break, continue, yield

# %%
company = 'Amazon'
Company = 'Google'

# %%
print(company)
print(Company)
# Out:
# Amazon
# Google

# %% [markdown]
# ## Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and False #and
# Out:
# False

# %%
True or False #or
# Out:
# True

# %%
not True #negation
# Out:
# False

# %%
not False
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
bool(0) #bool of zero is false and bool of True is One
# Out:
# False

# %%
a=1
if bool(a) == True:

    print("True")
# Out:
# True

# %% [markdown]
# ## Typecasting
#
# converting one datatype to another

# %%
str(23)  #number is converted to string
# Out:
# '23'

# %%
int('23')  #string converted to number
# Out:
# 23

# %% [markdown]
# ## Dynamic Typing
#
# Python is dynamic typing lang, we don't have to define the datatype of the variable while creating a varible
#
# Compiler on the runtime will be able to understand which type of variable it is
#
# See the example of 'a' varible below

# %%
a = 12

# %%
str1 = "Vishal"
a= "var"

# %%
int('abcd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 int('abcd')
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
int('123')
# Out:
# 123

# %% [markdown]
# ## Concatenation
#
# Concatenation between different ypes

# %%
"1" + "1"  #concatenation example
# Out:
# '11'

# %%
int('1') + int('1')
# Out:
# 2

# %%
int('1') + "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 int('1') + "1"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
"1" * 100  #string
# Out:
# '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111'

# %%
1 * 100 #number
# Out:
# 100
